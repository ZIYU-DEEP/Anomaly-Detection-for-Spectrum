# %%
import numpy as np
import os
import pickle
import joblib
import sys
import glob
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
from scipy.signal import correlate
import seaborn as sea
# %config InlineBackend.figure_format = 'retina'

# %%
window_size = str(1000)
normal_name = 'ryerson_train'
abnormal_name = 'ryerson_ab_train_sigOver'

# %%
normal_file = '/net/adv_spectrum/array_data_rss/{}_normal_{}_rss.npy'.format(normal_name, window_size)
abnormal_file = '/net/adv_spectrum/array_data_rss/{}_abnormal_{}_rss.npy'.format(abnormal_name, window_size)

# %%
normal_data = np.load(normal_file)
abnormal_data = np.load(abnormal_file)

# %%
normal_data = normal_data[:abnormal_data.shape[0]]

# %%
normal_corrs = []

# %%
normal_corrs = []
for i in range(len(normal_data)):
    normal_corrs.append(correlate(normal_data[i, :], abnormal_data[i, :])[0])

# %%
for i in range(len(normal_data)):
    normal_corrs.append(correlate(normal_data[i, :], abnormal_data[i, :])[0])

# %%
normal_corrs = np.array(normal_corrs)

# %%
normal_corrs.shape
# Out:
# (3588,)

# %%
plt.figure(figsize=(10, 6))
plt.plot(normal_corrs[:100])

# %%
X.shape
# Out:
# (3916000,)

# %%
normal_1 = normal_data[:-1, :]
normal_2 = normal_data[1:, :]
abnormal_1 = abnormal_data[:-1, :]
abnormal_2 = abnormal_data[1:, :]

normal_corrs = []

for i in range(len(normal_1)):
    normal_corrs.append(correlate(normal_1[i], normal_2[i])[0])

normal_corrs = np.array(normal_corrs)

abnormal_corrs = []

for i in range(len(abnormal_1)):
    abnormal_corrs.append(correlate(abnormal_1[i], abnormal_2[i])[0])

abnormal_corrs = np.array(abnormal_corrs)

# %%
sea.distplot(normal_corrs)

# %%
sea.distplot(abnormal_corrs)

# %%
th = np.quantile(normal_corrs, 0.90)
scores = np.where(abnormal_corrs > th, 1, 0).reshape(-1)
scores.sum() / scores.size
# Out:
# 0.04815588030619346

# %%
th = np.quantile(normal_corrs, 0.95)
scores = np.where(abnormal_corrs > th, 1, 0).reshape(-1)
scores.sum() / scores.size
# Out:
# 0.020153096729297146
